# %%
# @title
import os

# ==========================================
# 1. CHANGE THESE VARIABLES FOR EACH RUN
# ==========================================
topic_name = "Differential Equations"
batch_no = "3"


# Sample
# Paste your CSV text right here between the triple quotes (""")
csv_data = """
question_id,topic,node_names
Q_M_00_201,Differential Equations,Solution Curve Intersection and Post-Solve Geometry
Q_M_00_202,Differential Equations,Auxiliary Differential Equation Derivation
Q_M_00_203,Differential Equations,Disguise Unmasking
Q_M_00_204,Differential Equations,Disguise Unmasking
Q_M_00_205,Differential Equations,Geometric Property Reverse-Engineering
Q_M_00_206,Differential Equations,Integrating Factor Extraction from Non-Standard Groupings
Q_M_00_207,Differential Equations,Disguise Unmasking
Q_M_00_208,Differential Equations,Disguise Unmasking;Solution Curve Intersection and Post-Solve Geometry
Q_M_00_209,Differential Equations,Disguise Unmasking;Solution Curve Intersection and Post-Solve Geometry
Q_M_00_210,Differential Equations,Solution Curve Intersection and Post-Solve Geometry
Q_M_00_211,Differential Equations,Family Reconstruction
Q_M_00_212,Differential Equations,Integrating Factor Extraction from Non-Standard Groupings
Q_M_00_213,Differential Equations,Integrating Factor Extraction from Non-Standard Groupings;Solution Curve Intersection and Post-Solve Geometry
Q_M_00_214,Differential Equations,Integrating Factor Extraction from Non-Standard Groupings
"""
output_folder = "dna_nodes_output"

# This line ensures it uses the SAME directory every time without overwriting it
os.makedirs(output_folder, exist_ok=True)

# Format the file name (e.g., 3D_geometry_02.csv)
file_name = f"{topic_name.replace(' ', '_')}_{batch_no}.csv"
file_path = os.path.join(output_folder, file_name)

# Save the text as a new CSV file inside that same directory
with open(file_path, "w", encoding="utf-8") as f:
    f.write(csv_data.strip())

print(f"✅ Added new file to folder! Saved as: {file_path}")
# Out:
# ✅ Added new file to folder! Saved as: dna_nodes_output/Differential_Equations_3.csv

# %%
# @title
# !zip -r dna_nodes_output.zip dna_nodes_output/
from google.colab import files
files.download('dna_nodes_output.zip')

# %% [markdown]
# concept code

# %%
# @title
import os

# ==========================================
# 1. CHANGE THESE VARIABLES FOR EACH RUN
# ==========================================
topic_name = "Matrices And Determinants"
batch_no = "1"

# Paste your CSV text right here between the triple quotes (""")
csv_data = """

"""
output_folder = "concept_output"

# This line ensures it uses the SAME directory every time without overwriting it
os.makedirs(output_folder, exist_ok=True)

# Format the file name (e.g., 3D_geometry_02.csv)
file_name = f"{topic_name.replace(' ', '_')}_{batch_no}.csv"
file_path = os.path.join(output_folder, file_name)

# Save the text as a new CSV file inside that same directory
with open(file_path, "w", encoding="utf-8") as f:
    f.write(csv_data.strip())

print(f"✅ Added new file to folder! Saved as: {file_path}")
# Out:
# ✅ Added new file to folder! Saved as: concept_output/Matrices_And_Determinants_1.csv

# %%
# @title
# !zip -r concept_output.zip concept_output/
from google.colab import files
files.download('concept_output.zip')

# %% [markdown]
# error code

# %%
# @title
import os

# ==========================================
# 1. CHANGE THESE VARIABLES FOR EACH RUN
# ==========================================
topic_name = "Sets And Relations"
batch_no = "2"

# Paste your CSV text right here between the triple quotes (""")
csv_data = """
question_id,topic,error_names
Q_M_22_077,Sets And Relations,Transitive Closure Undercount
Q_M_22_078,Sets And Relations,Off-by-One in Enumeration
Q_M_22_079,Sets And Relations,Off-by-One in Enumeration
Q_M_22_080,Sets And Relations,Transitive Closure Undercount
Q_M_22_081,Sets And Relations,Product-Set Index Confusion
Q_M_22_082,Sets And Relations,Inclusion-Exclusion Sign Error
Q_M_22_083,Sets And Relations,Symmetry-Reflexivity Conflation
Q_M_22_084,Sets And Relations,Symmetry-Reflexivity Conflation
Q_M_22_085,Sets And Relations,Transitive Closure Undercount
Q_M_22_086,Sets And Relations,Symmetry-Reflexivity Conflation
Q_M_22_087,Sets And Relations,Off-by-One in Enumeration
Q_M_22_088,Sets And Relations,Product-Set Index Confusion
Q_M_22_089,Sets And Relations,Symmetry-Reflexivity Conflation
Q_M_22_090,Sets And Relations,Transitive Closure Undercount
Q_M_22_091,Sets And Relations,Off-by-One in Enumeration
Q_M_22_092,Sets And Relations,Off-by-One in Enumeration
Q_M_22_093,Sets And Relations,Off-by-One in Enumeration
Q_M_22_094,Sets And Relations,Off-by-One in Enumeration
Q_M_22_095,Sets And Relations,Transitive Closure Undercount
Q_M_22_096,Sets And Relations,Off-by-One in Enumeration
Q_M_22_097,Sets And Relations,Off-by-One in Enumeration
Q_M_22_098,Sets And Relations,Off-by-One in Enumeration
Q_M_22_099,Sets And Relations,Off-by-One in Enumeration
Q_M_22_100,Sets And Relations,Inclusion-Exclusion Sign Error
Q_M_22_101,Sets And Relations,Off-by-One in Enumeration
Q_M_22_102,Sets And Relations,Inclusion-Exclusion Sign Error
Q_M_22_103,Sets And Relations,Domain Boundary Misread in Absolute-Value Sets
Q_M_22_104,Sets And Relations,Off-by-One in Enumeration
Q_M_22_105,Sets And Relations,Off-by-One in Enumeration
Q_M_22_106,Sets And Relations,Off-by-One in Enumeration
Q_M_22_107,Sets And Relations,Inclusion-Exclusion Sign Error
"""

header = "question_id,topic,error_names"
start_index = csv_data.find(header)

if start_index != -1:
    # If found, slice the string to only keep the header and everything below it
    clean_csv_data = csv_data[start_index:].strip()
else:
    # Fallback just in case the LLM messes up the header format entirely
    clean_csv_data = csv_data.strip()

# ==========================================
# 3. SAVE THE FILE
# ==========================================
output_folder = "error_output"

# This line ensures it uses the SAME directory every time without overwriting it
os.makedirs(output_folder, exist_ok=True)

# Format the file name (e.g., 3D_geometry_02.csv)
file_name = f"{topic_name.replace(' ', '_')}_{batch_no}.csv"
file_path = os.path.join(output_folder, file_name)

# Save the cleaned text as a new CSV file
with open(file_path, "w", encoding="utf-8") as f:
    f.write(clean_csv_data)

print(f"✅ Added new file to folder! Saved as: {file_path}")
# Out:
# ✅ Added new file to folder! Saved as: error_output/Sets_And_Relations_2.csv

# %%
# @title
# !zip -r error_output.zip error_output/
from google.colab import files
files.download('error_output.zip')
# Out:
#   adding: error_output/ (stored 0%)
#   adding: error_output/Permutations_And_Combinations_3.csv (deflated 85%)
#   adding: error_output/Matrices_And_Determinants_3.csv (deflated 89%)
#   adding: error_output/Permutations_And_Combinations_2.csv (deflated 89%)
#   adding: error_output/Quadratic_Equation_And_Inequalities_2.csv (deflated 89%)
#   adding: error_output/Quadratic_Equation_And_Inequalities_1.csv (deflated 90%)
#   adding: error_output/Logarithm_1.csv (deflated 57%)
#   adding: error_output/Limits_Continuity_And_Differentiability_2.csv (deflated 90%)
#   adding: error_output/Area_Under_The_Curves_2.csv (deflated 88%)
#   adding: error_output/Area_Under_The_Curves_3.csv (deflated 64%)
#   adding: error_output/Matrices_And_Determinants_1.csv (deflated 89%)
#   adding: error_output/Matrices_And_Determinants_5.csv (deflated 80%)
#   adding: error_output/Quadratic_Equation_And_Inequalities_3.csv (deflated 77%)
# ...
